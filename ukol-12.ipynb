# %%
import pandas

# %%
import requests

zam_praha = requests.get("https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/zam_praha.csv")
open("zam_praha.csv", "wb").write(zam_praha.content)

zam_plzen = requests.get("https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/zam_plzeň.csv")
open("zam_plzeň.csv", "wb").write(zam_plzen.content)

zam_liberec = requests.get("https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/zam_liberec.csv")
open("zam_liberec.csv", "wb").write(zam_liberec.content)

platy = requests.get("https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/platy_2021_02.csv")
open("platy_2021_02.csv", "wb").write(platy.content)

vykazy = requests.get("https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/vykazy.csv")
open("vykazy.csv", "wb").write(vykazy.content)
# Out:
# 623

# %%
zam_liberec=pandas.read_csv("zam_liberec.csv")
zam_plzen=pandas.read_csv("zam_plzeň.csv")
zam_praha=pandas.read_csv("zam_praha.csv")
vykazy=pandas.read_csv("vykazy.csv")
platy=pandas.read_csv("platy_2021_02.csv")

# %%
zam_praha["mesto"]="Praha"
zam_liberec["mesto"]="Liberec"
zam_plzen["mesto"]="Plzeň"

# %%
zamestnanci=pandas.concat([zam_liberec,zam_plzen,zam_praha], ignore_index=True)
zamestnanci
# Out:
#           jmeno    prijimeni   telefonni_cislo  cislo_zamestnance    mesto
# 0          Nela      Šťastná       728 454 176                 83  Liberec
# 1       Heather      Marková       604 404 522                 84  Liberec
# 2        Krista  Procházková  +421 50 444 5544                 85  Liberec
# 3      Jennifer        Brown       775 545 190                 86  Liberec
# 4     Ladislava    Blackwell  +421 913 487 200                 87  Liberec
# 5        Robert       Macias  +421 49 929 6856                 88  Liberec
# 6          Dana        Reyes  +421 904 153 942                 90  Liberec
# 7         Vasyl       Veselý       603 759 413                 92  Liberec
# 8         Randy       Veselý       777 149 125                 95  Liberec
# 9        Audrey        Allen  +421 908 839 506                 96  Liberec
# 10         Ivan       Bartoš       603 226 051                 99  Liberec
# ...

# %%
zamestnanci_platy=pandas.merge(platy,zamestnanci)
zamestnanci_platy
# Out:
#     cislo_zamestnance     plat        jmeno    prijimeni   telefonni_cislo  \
# 0                   3  54900.0        Stacy  Pospíšilová       727 293 880
# 1                   6  54800.0        Matěj         Král       770 787 377
# 2                   7  36400.0       Amanda       Wilson  +421 52 656 7231
# 3                   8  47900.0        Angel       Wilson  +421 52 135 2491
# 4                  16  34200.0        Radim      Kopecký  +421 917 371 226
# 5                  18  35400.0     Miroslav         Reed       774 829 074
# 6                  21  54200.0       Emilie       Powell       731 380 539
# 7                  22  34400.0       Nikola         Wade       726 763 154
# 8                  23  39000.0    Katherine         Reed       726 214 968
# 9                  24  44200.0        Kayla     Urbanová       737 772 985
# 10                 26  59600.0        Roman       Moreno       722 284 985
# ...

# %% [markdown]
# Už tu nepracuje 55-42=13 zaměstnanců.

# %% [markdown]
# Ukol 12

# %%
import matplotlib.pyplot as plt
zamestnanci_platy.hist(["plat"], bins=[30000,35000,40000,45000,50000,55000,60000])
plt.show()

# %%
zamestnanci_platy.hist(["plat"], by=["mesto"], bins=[30000,35000,40000,45000,50000,55000,60000])
plt.show()

# %%
teploty=pandas.read_csv("temperature.csv")
teploty.head()
# Out:
#    Region  Country     City  Day  AvgTemperature
# 0  Africa  Algeria  Algiers    1            62.0
# 1  Africa  Algeria  Algiers    2            62.2
# 2  Africa  Algeria  Algiers    3            65.7
# 3  Africa  Algeria  Algiers    4            69.8
# 4  Africa  Algeria  Algiers    5            63.8

# %%
vybrana_mesta=teploty[teploty["City"].isin(["Helsinki", "Miami Beach", "Tokyo"])]
prumer=vybrana_mesta.groupby("City")["AvgTemperature"].mean()
prumer
# Out:
# City
# Helsinki       36.993333
# Miami Beach    76.823333
# Tokyo          55.920000
# Name: AvgTemperature, dtype: float64

# %%
cities=["Helsinki", "Miami Beach", "Tokyo"]
vybrana_mesta=teploty[teploty["City"].isin(cities)]
data_pro_graf=vybrana_mesta.iloc[:,[2,4]]
data_pro_graf.groupby(["City"]).boxplot(subplots=False, ylabel="Temp", whis=[0, 100])
plt.show()
# Out:
# /var/folders/jx/4ww3zyx56p768c3mblx8yw3h0000gn/T/ipykernel_28640/2759354100.py:4: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   data_pro_graf.groupby(["City"]).boxplot(subplots=False, ylabel="Temp", whis=[0, 100])
